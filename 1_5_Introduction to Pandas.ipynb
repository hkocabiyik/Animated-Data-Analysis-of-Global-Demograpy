# %%
# 1. read the file into a DataFrame
import pandas as pd

df = pd.read_csv("data/continents.csv", sep=";")
df
# Out:
#          continent    country
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
# [194 rows x 2 columns]

# %%
#2. display the number of rows and columns
df.shape
# Out:
# (194, 2)

# %%
#3. display the first 5 countries in the alphabet
df.head()
# Out:
#   continent   country
# 0    Africa   Algeria
# 1    Africa    Angola
# 2    Africa     Benin
# 3    Africa  Botswana
# 4    Africa   Burkina

# %%
import numpy as np
# 4. which continent has the most countries?
df.groupby(by=['continent']).count()
# Out:
#                        country
# continent
# Africa                      54
# Asia                        44
# Australia and Oceania       14
# Europe                      47
# North America               23
# South America               12

# %%
#5. find out on which continent Cyprus is
df[df["country"]=="Cyprus"]
# Out:
#     continent country
# 108    Europe  Cyprus

# %%
#6. define a DataFrame with all African countries
africa=df[df["continent"]=="Africa"]
africa
# Out:
#    continent                        country
# 0     Africa                        Algeria
# 1     Africa                         Angola
# 2     Africa                          Benin
# 3     Africa                       Botswana
# 4     Africa                        Burkina
# 5     Africa                        Burundi
# 6     Africa                       Cameroon
# 7     Africa                     Cape Verde
# 8     Africa       Central African Republic
# 9     Africa                           Chad
# 10    Africa                        Comoros
# 11    Africa                          Congo
# 12    Africa  Congo, Democratic Republic of
# 13    Africa                       Djibouti
# 14    Africa                          Egypt
# 15    Africa              Equatorial Guinea
# 16    Africa                        Eritrea
# 17    Africa                       Ethiopia
# 18    Africa                          Gabon
# 19    Africa                         Gambia
# ...

# %%
# 7. define a DataFrame with countries 80 through 100
subset = df.iloc[80:100]
subset
# Out:
#    continent               country
# 80      Asia                 Nepal
# 81      Asia                  Oman
# 82      Asia              Pakistan
# 83      Asia           Philippines
# 84      Asia                 Qatar
# 85      Asia    Russian Federation
# 86      Asia          Saudi Arabia
# 87      Asia             Singapore
# 88      Asia             Sri Lanka
# 89      Asia                 Syria
# 90      Asia            Tajikistan
# 91      Asia              Thailand
# 92      Asia                Turkey
# 93      Asia          Turkmenistan
# 94      Asia  United Arab Emirates
# 95      Asia            Uzbekistan
# 96      Asia               Vietnam
# 97      Asia                 Yemen
# 98    Europe               Albania
# 99    Europe               Andorra

# %%
# 8. select every second country
df.iloc[::2, 1]
# Out:
# 0                       Algeria
# 2                         Benin
# 4                       Burkina
# 6                      Cameroon
# 8      Central African Republic
#                  ...
# 184                      Brazil
# 186                    Colombia
# 188                      Guyana
# 190                        Peru
# 192                     Uruguay
# Name: country, Length: 97, dtype: object

# %%
# Step 1: Load the life expectancy data from the gapminder_lifeexpectancy.xlsx file into a pandas DataFrame.
import pandas as pd

lifeexp = pd.read_excel("data/gapminder_lifeexpectancy.xlsx")
lifeexp
# Out:
#            Life expectancy  1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  \
# 0                 Abkhazia     NaN     NaN     NaN     NaN     NaN     NaN
# 1              Afghanistan   28.21   28.20   28.19   28.18   28.17   28.16
# 2    Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN
# 3                  Albania   35.40   35.40   35.40   35.40   35.40   35.40
# 4                  Algeria   28.82   28.82   28.82   28.82   28.82   28.82
# ..                     ...     ...     ...     ...     ...     ...     ...
# 255             Yugoslavia     NaN     NaN     NaN     NaN     NaN     NaN
# 256                 Zambia   32.60   32.60   32.60   32.60   32.60   32.60
# 257               Zimbabwe   33.70   33.70   33.70   33.70   33.70   33.70
# 258                  Åland     NaN     NaN     NaN     NaN     NaN     NaN
# 259            South Sudan   26.67   26.67   26.67   26.67   26.67   26.67
#
# ...

# %%
#Step 2: Select a few columns with years. Note that the columns read from Excel are integer values.
lifeexp = lifeexp[[1950, 1975, 2000, 2015]]
lifeexp
# Out:
#      1950.0  1975.0  2000.0  2015.0
# 0       NaN     NaN     NaN     NaN
# 1     26.85   39.61    50.1    53.8
# 2       NaN     NaN     NaN     NaN
# 3     54.48   69.77    74.7    78.0
# 4     42.77   55.24    73.3    76.4
# ..      ...     ...     ...     ...
# 255     NaN     NaN     NaN     NaN
# 256   42.85   56.70    44.8    56.7
# 257   48.46   59.41    47.9    59.3
# 258     NaN     NaN    80.0     NaN
# 259   28.14   42.93    54.4    56.1
#
# [260 rows x 4 columns]

# %%
#Step 3: Draw a histogram for 2015 with the default settings.
import matplotlib.pyplot as plt

lifeexp[2015].hist()
plt.savefig('histo.png')

# %%
#Step 4: Try a few values for the number of bins
lifeexp[2015].hist(bins=5)
lifeexp[2015].hist(bins=10)
lifeexp[2015].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
#Step 5: Modify the plot using some matplotlib functions.
plt.hist(lifeexp[2015])
plt.title('Life Expectancy& Number of Countries ')
plt.xlabel('Life Expectany')
plt.ylabel('Number of Countries')
plt.show()

# %%
lifeexp[2015].value_counts()
# Out:
# 71.50    4
# 72.90    4
# 77.60    4
# 65.90    3
# 81.00    3
#         ..
# 76.69    1
# 77.58    1
# 65.80    1
# 65.20    1
# 56.10    1
# Name: 2015.0, Length: 140, dtype: int64

# %%
#Step 6: Set the min/max x and y values with plt.axis.
import numpy as np
lifeexp[2015].hist(alpha=0.3, histtype='bar')
plt.title('Life Expectancy& Number of Countries ')
plt.xlabel('Life Expectany')
plt.ylabel('Number of Countries')
plt.axis([lifeexp[2015].min(), lifeexp[2015].max(),0,50])
# Out:
# (47.1, 84.8, 0.0, 50.0)

# %%
#Step 8: Set the resolution of the image that is written.
plt.savefig('histo2.png', dpi=150)

# %%
#Step 8b: Set the resolution of the image that is written.
plt.savefig('histo3.svg', dpi=150)

# %% [markdown]
# # **Bonus GOAL Data Round-Trip
